# %%
import kagglehub

save_path = "data"

# Download latest version
path = kagglehub.dataset_download(handle = "serpilturanyksel/adult-income", output_dir = save_path)

print("Path to dataset files:", path)
# Out:
# Path to dataset files: data
